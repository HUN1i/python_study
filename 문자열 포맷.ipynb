# %%
# 출력하려는 값을 콤마로 구분하면 공백넣어서 출력됨. + 해주면 합쳐짐(알고있음)
# 포맷 방법
# 1.c 방식
asd=123
asdasd=123123
print('{},{}'.format(asd,asdasd))
# 2. c 방식 2, 순서 정할 수 있음
print('{0},{1}'.format(asd,asdasd))
# 3. f-string(변수 바로 넣기)
print(f'{asd},{asdasd}')
