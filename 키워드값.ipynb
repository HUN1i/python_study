# %%
# 함수 사용 시에 고려할 것이 많음.
# 기본값으로 설정하면 고려할 필요가 없을 것
def fruit(is_vip=False,
          is_banana=False,
          is_apple=False): 
        if is_vip==False:
              print('15000')
        else:print('10000')
        if is_banana==False:
            print('0')
        else: print('5000')
        if is_apple==True:print("7000")
        else :print("0")
# 이럴 땐 함수 부를 때 
price=fruit(is_banana=True)#이렇게 해주면 바나나만 True가 된다
print(f"{fruit}")
