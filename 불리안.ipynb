# %%
# 불리안으로 바꾸는 형변환- bool()
# 값이 있는 경우 - "ㅁㄴㅇ","     "
# 값이 없는 경우 - 0, none, ""
# 불리안은 참이면 True, 거짓이면 False, 값이 있으면 True, 값이 없으면 False

# 활용
print(3>5)
print(bool(None))
print(bool('False'))
print(bool(""))
