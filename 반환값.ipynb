# %%
# 반환값:함수 내에서 처리된 결과를 반환함
# 양식: def 함수(전달값):
#           문장
#           return 반환값
# c랑 거의 같은 거 같다.
def banana():
    return '10000원'

fruit=banana()# 함수로 덮었기 때문에 fruit='10000원'으로 볼 수 있음
print(f"바나나는 {fruit}")

def apple(is_vip):# true이면 단골, false이면 손님
    if is_vip==True:
        return '5000원'
    else:
        return '10000원'
fruit=apple(True),banana()
print(f"원래 가격은 {banana}, 단골 가격은 {apple}dn")
    #함수 탈출해서 이상하게 나옴
