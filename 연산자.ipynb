# %%
# +,-,*,/,%는 c와 같음
# //는 몪, **는 거듭제곱임
# 비교 연산자는 c와 같음,불리안 형태로 나옴
# 논리 연산자는 비교 연산자로 써줘야함

# 활용
asd=int('123')
print(asd + asd, asd - asd, asd * asd, asd % asd,asd / asd)

asdf=asd>asd+1
print(asdf)
