# %%
# 비슷한 코드를 일일이 수정하는 불편함
# 이를 해결하기 위한 것:def()에서 괄호에 해당하는 전달값
def food(asd):#전달값 지정
    print(f"{asd}음식")
#예시문
foood1='banana'
food(foood1)#출력할 전달값 지정

foood2='apple'
food(foood2)#출력할 전달값 지정 2
# 위의 '음식'부분을 바꿔주면 밑에 출력도 잘 바뀐다
# 전달값은 여러개 전달 가능, 함수 내에서만 사용 가능
