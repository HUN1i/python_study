# %%
# open(파일명,열기모드,인코딩)으로 파일을 불러올 수 있다
# r(읽기),w(쓰기),a(이어쓰기)
f=open('for.ipynb','r',encoding='utf8')
contents=f.read
print(f)
# 열었으면 닫아야 함
f.close()
# 지금은 파일이 찾아지지 않아서 에러
# 덮어쓸 때는 f.write('asdads')
