# %%
# 반복 대상: 리스트.튜플.딕셔너리
my_list = [1,2,3]
for i in my_list:
    print(i)
# 이거는 c에서 for문 변수 입력받은거 만큼 돌리는 거로 생각하면 될듯
person={'asd','123',1}
for i in person:
    print(i)
# 문자열도 나온다
asd= 'asdasd'
for i in asd:
    print(i)
# 일반문자열은 끊겨서 나온다
